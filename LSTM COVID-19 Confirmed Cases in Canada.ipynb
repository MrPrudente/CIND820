# %% [markdown]
# LSTM

# %% [markdown]
# Packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
# fix random seed for reproducibility
numpy.random.seed(7)

# %% [markdown]
# Importing dataset

# %%
# read the dataset into python
df = pd.read_csv('https://data.ontario.ca/dataset/f4f86e54-872d-43f8-8a86-3892fd3cb5e6/resource/ed270bb8-340b-41f9-a7c6-e8ef587e6d11/download/covidtesting.csv', index_col='Reported Date',parse_dates=True)
dataset = df.values
dataset = dataset.astype('float32')
# Out:
#                Confirmed Negative  Presumptive Negative  Presumptive Positive  \
# Reported Date
# 2020-02-06                    NaN                   NaN                   1.0
# 2020-02-07                    NaN                   NaN                   2.0
# 2020-02-08                    NaN                   NaN                   1.0
# 2020-02-09                    NaN                   NaN                   0.0
# 2020-02-10                    NaN                   NaN                   0.0
#
#                Confirmed Positive  Resolved  Deaths  Total Cases  \
# Reported Date
# 2020-02-06                    NaN       NaN     NaN          NaN
# 2020-02-07                    NaN       NaN     NaN          NaN
# 2020-02-08                    1.0       NaN     NaN          1.0
# 2020-02-09                    2.0       NaN     NaN          2.0
# 2020-02-10                    2.0       NaN     NaN          2.0
#
#                Total patients approved for testing as of Reporting Date  \
# Reported Date
# 2020-02-06                                                   NaN
# 2020-02-07                                                   NaN
# 2020-02-08                                                   NaN
# 2020-02-09                                                   NaN
# 2020-02-10                                                   NaN
#
#                Total tests completed in the last day  \
# Reported Date
# 2020-02-06                                       NaN
# 2020-02-07                                       NaN
# 2020-02-08                                       NaN
# 2020-02-09                                       NaN
# 2020-02-10                                       NaN
#
#                Percent positive tests in last day  ...  \
# Reported Date                                      ...
# 2020-02-06                                    NaN  ...
# 2020-02-07                                    NaN  ...
# 2020-02-08                                    NaN  ...
# 2020-02-09                                    NaN  ...
# 2020-02-10                                    NaN  ...
#
#                Total Positive LTC Resident Cases  \
# Reported Date
# 2020-02-06                                   NaN
# 2020-02-07                                   NaN
# 2020-02-08                                   NaN
# 2020-02-09                                   NaN
# 2020-02-10                                   NaN
#
#                Total Positive LTC HCW Cases  Total LTC Resident Deaths  \
# Reported Date
# 2020-02-06                              NaN                        NaN
# 2020-02-07                              NaN                        NaN
# 2020-02-08                              NaN                        NaN
# 2020-02-09                              NaN                        NaN
# 2020-02-10                              NaN                        NaN
#
#                Total LTC HCW Deaths  Total_Lineage_B.1.1.7_Alpha  \
# Reported Date
# 2020-02-06                      NaN                          NaN
# 2020-02-07                      NaN                          NaN
# 2020-02-08                      NaN                          NaN
# 2020-02-09                      NaN                          NaN
# 2020-02-10                      NaN                          NaN
#
#                Total_Lineage_B.1.351_Beta  Total_Lineage_P.1_Gamma  \
# Reported Date
# 2020-02-06                            NaN                      NaN
# 2020-02-07                            NaN                      NaN
# 2020-02-08                            NaN                      NaN
# 2020-02-09                            NaN                      NaN
# 2020-02-10                            NaN                      NaN
#
#                Total_Lineage_B.1.617.2_Delta  deaths_data_cleaning  \
# Reported Date
# 2020-02-06                               NaN                   NaN
# 2020-02-07                               NaN                   NaN
# 2020-02-08                               NaN                   NaN
# 2020-02-09                               NaN                   NaN
# 2020-02-10                               NaN                   NaN
#
#                newly_reported_deaths
# Reported Date
# 2020-02-06                       NaN
# 2020-02-07                       NaN
# 2020-02-08                       NaN
# 2020-02-09                       NaN
# 2020-02-10                       NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# Checking for Nulls

# %%
df.isnull()
df.isnull().sum()
# Out:
# Confirmed Negative                                           710
# Presumptive Negative                                         745
# Presumptive Positive                                         732
# Confirmed Positive                                             2
# Resolved                                                      12
# Deaths                                                        40
# Total Cases                                                    2
# Total patients approved for testing as of Reporting Date       6
# Total tests completed in the last day                         69
# Percent positive tests in last day                            73
# Under Investigation                                            0
# Number of patients hospitalized with COVID-19                 56
# Number of patients in ICU due to COVID-19                     86
# Number of patients in ICU, testing positive for COVID-19      56
# Number of patients in ICU, testing negative for COVID-19      86
# Number of patients in ICU on a ventilator due to COVID-19     86
# Num. of patients in ICU on a ventilator testing positive      56
# Num. of patients in ICU on a ventilator testing negative      86
# Total Positive LTC Resident Cases                            106
# Total Positive LTC HCW Cases                                 110
# Total LTC Resident Deaths                                    103
# Total LTC HCW Deaths                                         103
# Total_Lineage_B.1.1.7_Alpha                                  471
# Total_Lineage_B.1.351_Beta                                   475
# Total_Lineage_P.1_Gamma                                      487
# Total_Lineage_B.1.617.2_Delta                                609
# deaths_data_cleaning                                         581
# newly_reported_deaths                                        581
# dtype: int64

# %% [markdown]
# Changing Nulls to Mean value

# %%
df.fillna(df.mean(), inplace=True)

# %% [markdown]
# Checking Nulls

# %%
df.isnull()
df.isnull().sum()
# Out:
# Confirmed Negative                                           0
# Presumptive Negative                                         0
# Presumptive Positive                                         0
# Confirmed Positive                                           0
# Resolved                                                     0
# Deaths                                                       0
# Total Cases                                                  0
# Total patients approved for testing as of Reporting Date     0
# Total tests completed in the last day                        0
# Percent positive tests in last day                           0
# Under Investigation                                          0
# Number of patients hospitalized with COVID-19                0
# Number of patients in ICU due to COVID-19                    0
# Number of patients in ICU, testing positive for COVID-19     0
# Number of patients in ICU, testing negative for COVID-19     0
# Number of patients in ICU on a ventilator due to COVID-19    0
# Num. of patients in ICU on a ventilator testing positive     0
# Num. of patients in ICU on a ventilator testing negative     0
# Total Positive LTC Resident Cases                            0
# Total Positive LTC HCW Cases                                 0
# Total LTC Resident Deaths                                    0
# Total LTC HCW Deaths                                         0
# Total_Lineage_B.1.1.7_Alpha                                  0
# Total_Lineage_B.1.351_Beta                                   0
# Total_Lineage_P.1_Gamma                                      0
# Total_Lineage_B.1.617.2_Delta                                0
# deaths_data_cleaning                                         0
# newly_reported_deaths                                        0
# dtype: int64

# %%
dataset = pandas.read_csv('https://data.ontario.ca/dataset/f4f86e54-872d-43f8-8a86-3892fd3cb5e6/resource/ed270bb8-340b-41f9-a7c6-e8ef587e6d11/download/covidtesting.csv', usecols=[1], engine='python')
plt.plot(dataset)
plt.show()
